# %% [markdown]
# # EDA
#
# ![](data:image/jpeg;base64,...)

# %% [markdown]
# Hypotheses - Persona William Rodriguez (Buyer)
#
# 2 people, wants two houses: one in the country (best timing, non-renovated) and one in the city (fast, central location). Houses should be reasonably close to each other.
#
# Country House
# William isn't in a hurry, doesn't care about neighbors, needs a quiet place to unwind, and owns a dog. Space, privacy and price matter more than polish or central location.
#
# H1 - Price vs renovation status
#
# Non-renovated houses (yr_renovated = 0) are on average cheaper than renovated houses of comparable size and location.
#
# Data: price, yr_renovated, sqft_living, zipcode
#
# Test: compare the median price of non-renovated houses against renovated ones, keeping size and zip code roughly similar so the comparison is fair

# %%
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")

plt.rcParams.update(
    {"figure.figsize": (8, 5), "axes.facecolor": "white", "axes.edgecolor": "black"}
)
plt.rcParams["figure.facecolor"] = "w"
pd.plotting.register_matplotlib_converters()
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# %% [markdown]
# reconnect to database

# %%
import psycopg2
from dotenv import load_dotenv
import os

load_dotenv()

# Use the correct variable names from your .env file
conn = psycopg2.connect(
    database=os.getenv("DATABASE"),
    user=os.getenv("USER_DB"),
    password=os.getenv("PASSWORD"),
    host=os.getenv("HOST"),
    port=os.getenv("PORT")
)

print(" Database connection successful!")
# Out:
#  Database connection successful!

# %% [markdown]
# #Step 1: Explore the data — Check columns & basic info

# %%
# Query the full dataset
query_string = "SELECT * FROM eda.king_county_house_sales LIMIT 1"
df_sqlalchemy = pd.read_sql(query_string, conn)

print(f"Columns available: {df_sqlalchemy.columns.tolist()}")
print(f"Total columns: {len(df_sqlalchemy.columns)}")
# Out:
# Columns available: ['date', 'price', 'house_id', 'id']
# Total columns: 4

# %%
import psycopg2
from psycopg2 import sql

cursor = conn.cursor()

# List all tables in the 'eda' schema
cursor.execute("""
    SELECT table_name 
    FROM information_schema.tables 
    WHERE table_schema = 'eda'
""")

tables = cursor.fetchall()
print("Tables in 'eda' schema:")
for table in tables:
    print(f"  - {table[0]}")

cursor.close()
# Out:
# Tables in 'eda' schema:
#   - king_county_house_details
#   - king_county_house_sales

# %%
cursor = conn.cursor()

cursor.execute("""
    SELECT column_name 
    FROM information_schema.columns 
    WHERE table_schema = 'eda' AND table_name = 'king_county_house_details'
    ORDER BY ordinal_position
""")

columns = cursor.fetchall()
print("Columns in king_county_house_details:")
for col in columns:
    print(f"  - {col[0]}")

cursor.close()
# Out:
# Columns in king_county_house_details:
#   - id
#   - bedrooms
#   - bathrooms
#   - sqft_living
#   - sqft_lot
#   - floors
#   - waterfront
#   - view
#   - condition
#   - grade
#   - sqft_above
#   - sqft_basement
#   - yr_built
#   - yr_renovated
#   - zipcode
#   - lat
#   - long
#   - sqft_living15
#   - sqft_lot15

# %% [markdown]
# Join both tables

# %%
# Query: JOIN sales with details using the common key
query_string = """
SELECT 
    s.date,
    s.price,
    s.house_id,
    d.id,
    d.bedrooms,
    d.bathrooms,
    d.sqft_living,
    d.sqft_lot,
    d.floors,
    d.waterfront,
    d.view,
    d.condition,
    d.grade,
    d.sqft_above,
    d.sqft_basement,
    d.yr_built,
    d.yr_renovated,
    d.zipcode,
    d.lat,
    d.long,
    d.sqft_living15,
    d.sqft_lot15
FROM eda.king_county_house_sales s
JOIN eda.king_county_house_details d ON s.house_id = d.id
"""

df_sqlalchemy = pd.read_sql(query_string, conn)

# df_h1_final is the working dataframe used throughout the rest of this notebook
df_h1_final = df_sqlalchemy.copy()

print(" Full dataset loaded!")
print(f"Shape: {df_h1_final.shape}")
print(f"\nColumns ({len(df_h1_final.columns)}):")
print(df_h1_final.columns.tolist())
print(f"\nFirst row:")
print(df_h1_final.head(1))
# Out:
#  Full dataset loaded!
# Shape: (21597, 22)
#
# Columns (22):
# ['date', 'price', 'house_id', 'id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']
#
# First row:
#          date      price    house_id          id  bedrooms  bathrooms  \
# 0  2014-10-13 221900.000  7129300520  7129300520     3.000      1.000
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0     1180.000  5650.000   1.000         NaN  ...      7    1180.000
#
#    sqft_basement  yr_built  yr_renovated  zipcode    lat     long  \
# 0          0.000      1955         0.000    98178 47.511 -122.257
#
#    sqft_living15  sqft_lot15
# 0       1340.000    5650.000
#
# [1 rows x 22 columns]

# %%
# Basic count of unique zipcodes
num_zipcodes = df_h1_final['zipcode'].nunique()
print(f"Total number of unique zipcodes: {num_zipcodes}")

# See all zipcodes and how many houses are in each
zipcode_counts = df_h1_final['zipcode'].value_counts().sort_index()
print("\nHouses per zipcode:")
print(zipcode_counts)

# Summary statistics about zipcode distribution
print(f"\nZipcode with most houses: {zipcode_counts.idxmax()} ({zipcode_counts.max()} houses)")
print(f"Zipcode with fewest houses: {zipcode_counts.idxmin()} ({zipcode_counts.min()} houses)")
print(f"Average houses per zipcode: {zipcode_counts.mean():.0f}")

# Identify Rural zip codes using only what's already in the original dataset:
# zipcode, lat, long. We approximate each zip code's land area from the
# bounding box of its houses' lat/long, then use housing density (sales per
# km^2) as a Rural/Urban signal - sparser areas are more likely Rural. No
# external reference data (e.g. RUCA) is used to make this classification.
km_per_deg_lat = 111.0
km_per_deg_lon = 111.0 * np.cos(np.radians(df_h1_final['lat'].mean()))

zip_stats = df_h1_final.groupby('zipcode').agg(
    n_sales=('price', 'count'),
    lat_min=('lat', 'min'), lat_max=('lat', 'max'),
    long_min=('long', 'min'), long_max=('long', 'max'),
)
zip_stats['area_km2'] = (
    (zip_stats['lat_max'] - zip_stats['lat_min']) * km_per_deg_lat
    * (zip_stats['long_max'] - zip_stats['long_min']) * km_per_deg_lon
)
zip_stats['density'] = zip_stats['n_sales'] / zip_stats['area_km2']

# Find the Rural/Urban split point automatically: sort zip codes by density,
# then find the largest natural gap (on a log scale) among the sparsest third
# of zip codes - excluding the single sparsest zip code, which is an extreme
# outlier on its own and would otherwise dominate the gap search.
sorted_density = zip_stats['density'].sort_values()
positions = pd.Series(range(len(sorted_density)), index=sorted_density.index)
log_density = np.log(sorted_density)
gaps = log_density.diff()
candidate_gaps = gaps.iloc[2:len(gaps) // 3]
split_zipcode = candidate_gaps.idxmax()
threshold = sorted_density.iloc[positions[split_zipcode] - 1]
print(f"\nNatural density break found: threshold = {threshold:.3f} houses/km2")

zip_stats['location_type'] = zip_stats['density'].apply(lambda d: 'Rural' if d <= threshold else 'Urban')
rural_zips_found = sorted(zip_stats[zip_stats['location_type'] == 'Rural'].index.tolist())
print(f"Rural zip codes identified from housing density alone: {rural_zips_found}")

df_h1_final = df_h1_final.drop(columns=['location_type'], errors='ignore').merge(
    zip_stats[['location_type']].reset_index(), on='zipcode', how='left'
)
location_counts = df_h1_final['location_type'].value_counts()
print(f"\nUrban vs Rural breakdown:")
print(location_counts)
# Out:
# Total number of unique zipcodes: 70
#
# Houses per zipcode:
# zipcode
# 98001    361
# 98002    199
# 98003    280
# 98004    317
# 98005    168
#         ...
# 98177    255
# 98178    262
# 98188    136
# 98198    280
# 98199    317
# Name: count, Length: 70, dtype: int64
#
# Zipcode with most houses: 98103 (602 houses)
# Zipcode with fewest houses: 98039 (50 houses)
# Average houses per zipcode: 309
#
# Natural density break found: threshold = 1.041 houses/km2
# Rural zip codes identified from housing density alone: [98010, 98014, 98019, 98022, 98024, 98045, 98070]
#
# Urban vs Rural breakdown:
# location_type
# Urban    20533
# Rural     1064
# Name: count, dtype: int64

# %%
# List all zipcodes with house counts
all_zipcodes = sorted(df_h1_final['zipcode'].unique())
print("All zipcodes in the dataset:\n")
for zipcode in all_zipcodes:
    count = len(df_h1_final[df_h1_final['zipcode'] == zipcode])
    print(f"Zipcode {zipcode}: {count} houses")
# Out:
# All zipcodes in the dataset:
#
# Zipcode 98001: 361 houses
# Zipcode 98002: 199 houses
# Zipcode 98003: 280 houses
# Zipcode 98004: 317 houses
# Zipcode 98005: 168 houses
# Zipcode 98006: 498 houses
# Zipcode 98007: 141 houses
# Zipcode 98008: 283 houses
# Zipcode 98010: 100 houses
# Zipcode 98011: 195 houses
# Zipcode 98014: 124 houses
# Zipcode 98019: 190 houses
# Zipcode 98022: 233 houses
# Zipcode 98023: 499 houses
# Zipcode 98024: 80 houses
# Zipcode 98027: 412 houses
# Zipcode 98028: 283 houses
# Zipcode 98029: 321 houses
# Zipcode 98030: 256 houses
# Zipcode 98031: 273 houses
# Zipcode 98032: 125 houses
# Zipcode 98033: 432 houses
# Zipcode 98034: 545 houses
# Zipcode 98038: 589 houses
# Zipcode 98039: 50 houses
# Zipcode 98040: 282 houses
# Zipcode 98042: 547 houses
# Zipcode 98045: 220 houses
# Zipcode 98052: 574 houses
# Zipcode 98053: 403 houses
# Zipcode 98055: 268 houses
# Zipcode 98056: 406 houses
# Zipcode 98058: 455 houses
# Zipcode 98059: 468 houses
# Zipcode 98065: 308 houses
# Zipcode 98070: 117 houses
# Zipcode 98072: 273 houses
# Zipcode 98074: 441 houses
# Zipcode 98075: 359 houses
# Zipcode 98077: 198 houses
# Zipcode 98092: 351 houses
# Zipcode 98102: 104 houses
# Zipcode 98103: 602 houses
# Zipcode 98105: 229 houses
# Zipcode 98106: 335 houses
# Zipcode 98107: 266 houses
# Zipcode 98108: 186 houses
# Zipcode 98109: 109 houses
# Zipcode 98112: 269 houses
# Zipcode 98115: 583 houses
# Zipcode 98116: 330 houses
# Zipcode 98117: 553 houses
# Zipcode 98118: 507 houses
# Zipcode 98119: 184 houses
# Zipcode 98122: 290 houses
# Zipcode 98125: 409 houses
# Zipcode 98126: 354 houses
# Zipcode 98133: 493 houses
# Zipcode 98136: 263 houses
# Zipcode 98144: 343 houses
# Zipcode 98146: 288 houses
# Zipcode 98148: 57 houses
# Zipcode 98155: 446 houses
# Zipcode 98166: 254 houses
# Zipcode 98168: 269 houses
# Zipcode 98177: 255 houses
# Zipcode 98178: 262 houses
# Zipcode 98188: 136 houses
# Zipcode 98198: 280 houses
# Zipcode 98199: 317 houses

# %% [markdown]
# Explore data to clean if needed

# %%
# Query the joined dataset
query_string = """
SELECT 
    s.date, s.price, s.house_id,
    d.id, d.bedrooms, d.bathrooms, d.sqft_living, d.sqft_lot, d.floors,
    d.waterfront, d.view, d.condition, d.grade, d.sqft_above, d.sqft_basement,
    d.yr_built, d.yr_renovated, d.zipcode, d.lat, d.long,
    d.sqft_living15, d.sqft_lot15
FROM eda.king_county_house_sales s
JOIN eda.king_county_house_details d ON s.house_id = d.id
"""

df_sqlalchemy = pd.read_sql(query_string, conn)
print(f" Dataset loaded: {df_sqlalchemy.shape}")
# Out:
#  Dataset loaded: (21597, 22)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Filter for rural properties only
df_rural = df_h1_final[df_h1_final['location_type'] == 'Rural'].copy()

# Create 3 size ranges using tertiles
df_rural['size_range'] = pd.qcut(df_rural['sqft_living'], q=3, labels=['Small', 'Medium', 'Large'])

# Derive renovation status from yr_renovated (H1 hypothesis: yr_renovated == 0 means non-renovated)
df_rural['renovation_status'] = df_rural['yr_renovated'].apply(
    lambda x: 'Non-Renovated' if x == 0 else 'Renovated'
)

# Get the actual sqft ranges for labeling
size_ranges_info = df_rural.groupby('size_range')['sqft_living'].agg(['min', 'max'])
print("Size Range Information:")
print(size_ranges_info)

# Create figure with 3 subplots
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle('Renovation Effect by Property Size in Rural Areas', fontsize=14, fontweight='bold')

size_categories = ['Small', 'Medium', 'Large']
colors = ['#FF6B6B', '#4ECDC4']

for idx, size_cat in enumerate(size_categories):
    df_size = df_rural[df_rural['size_range'] == size_cat]
    
    # Get sqft range for this category
    min_sqft = df_size['sqft_living'].min()
    max_sqft = df_size['sqft_living'].max()
    
    # Create box plot
    sns.boxplot(
        data=df_size,
        x='renovation_status',
        y='price',
        ax=axes[idx],
        palette=colors,
        width=0.6
    )
    
    # Set title with actual sqft range
    title = f'{size_cat} Properties\n{min_sqft:,} - {max_sqft:,} sqft'
    axes[idx].set_title(title, fontweight='bold', fontsize=12)
    axes[idx].set_xlabel('Renovation Status', fontsize=11)
    axes[idx].set_ylabel('Price ($)', fontsize=11)
    axes[idx].yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))
    axes[idx].grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()
# Out:
# Size Range Information:
#                 min      max
# size_range
# Small       430.000 1560.000
# Medium     1570.000 2280.000
# Large      2290.000 7420.000

# %%
from scipy.stats import mannwhitneyu

# H1 statistical test: compare non-renovated vs renovated median price,
# within each size tier, among Rural properties.
print("H1 - Price vs Renovation Status (Rural properties, by size tier)\n")
for size_cat in ['Small', 'Medium', 'Large']:
    df_size = df_rural[df_rural['size_range'] == size_cat]
    non_renovated = df_size[df_size['renovation_status'] == 'Non-Renovated']['price']
    renovated = df_size[df_size['renovation_status'] == 'Renovated']['price']

    stat, p_value = mannwhitneyu(non_renovated, renovated, alternative='two-sided')
    diff = non_renovated.median() - renovated.median()

    print(f"{size_cat} (n={len(df_size)}: {len(non_renovated)} non-renovated, {len(renovated)} renovated)")
    print(f"  Non-Renovated median: ${non_renovated.median():,.0f}  ·  Renovated median: ${renovated.median():,.0f}")
    print(f"  Difference (non-renovated - renovated): ${diff:,.0f}")
    print(f"  Mann-Whitney U p-value: {p_value:.3f}", "(significant)" if p_value < 0.05 else "(not statistically significant)")
    print()
# Out:
# H1 - Price vs Renovation Status (Rural properties, by size tier)
#
# Small (n=355: 263 non-renovated, 92 renovated)
#   Non-Renovated median: $278,000  ·  Renovated median: $275,000
#   Difference (non-renovated - renovated): $3,000
#   Mann-Whitney U p-value: 0.621 (not statistically significant)
#
# Medium (n=354: 277 non-renovated, 77 renovated)
#   Non-Renovated median: $375,000  ·  Renovated median: $370,000
#   Difference (non-renovated - renovated): $5,000
#   Mann-Whitney U p-value: 0.918 (not statistically significant)
#
# Large (n=355: 284 non-renovated, 71 renovated)
#   Non-Renovated median: $535,000  ·  Renovated median: $540,000
#   Difference (non-renovated - renovated): $-5,000
#   Mann-Whitney U p-value: 0.976 (not statistically significant)

# %% [markdown]
# Specific offers for the buyers based on hypothesis 1

# %%
# Filter for rural, non-renovated, medium size
df_candidates = df_rural[
    (df_rural['renovation_status'] == 'Non-Renovated') &
    (df_rural['size_range'] == 'Medium')
].copy()

# Sort by price (lowest first to show best value)
df_candidates = df_candidates.sort_values('price')

# Select top 2 houses
selected_houses = df_candidates.head(2)

# Display details
print("Two Non-Renovated Medium-Size Rural Properties:\n")
for idx, (i, row) in enumerate(selected_houses.iterrows(), 1):
    print(f"Property {idx}:")
    print(f"  Zipcode: {row['zipcode']}")
    print(f"  Price: ${row['price']:,.0f}")
    print(f"  Sqft Living: {row['sqft_living']:,}")
    print(f"  Bedrooms: {row['bedrooms']}")
    print(f"  Bathrooms: {row['bathrooms']}")
    print(f"  Year Built: {row['yr_built']}")
    print(f"  Lot Size: {row['sqft_lot']:,}")
# Out:
# Two Non-Renovated Medium-Size Rural Properties:
#
# Property 1:
#   Zipcode: 98022
#   Price: $195,000
#   Sqft Living: 1,580.0
#   Bedrooms: 3.0
#   Bathrooms: 1.75
#   Year Built: 1979
#   Lot Size: 7,875.0
# Property 2:
#   Zipcode: 98022
#   Price: $195,000
#   Sqft Living: 1,570.0
#   Bedrooms: 3.0
#   Bathrooms: 1.75
#   Year Built: 1991
#   Lot Size: 8,459.0

# %%
# Save as CSV (recommended - easy to inspect and share)
df_h1_final.to_csv('../data/processed/df_h1_final_cleaned.csv', index=False)
print("Saved: ../data/processed/df_h1_final_cleaned.csv")

# Optional: Also save as pickle (preserves exact data types)
import pickle
with open('../data/processed/df_h1_final_cleaned.pkl', 'wb') as f:
    pickle.dump(df_h1_final, f)
print("Saved: ../data/processed/df_h1_final_cleaned.pkl")
# Out:
# Saved: ../data/processed/df_h1_final_cleaned.csv
# Saved: ../data/processed/df_h1_final_cleaned.pkl

# %%
import pandas as pd

df_h1_final = pd.read_csv('../data/processed/df_h1_final_cleaned.csv')

print(f"Data loaded: {len(df_h1_final)} rows")
print(f"Columns: {df_h1_final.columns.tolist()}")
print(df_h1_final.head())
# Out:
# Data loaded: 21597 rows
# Columns: ['date', 'price', 'house_id', 'id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'location_type']
#          date      price    house_id          id  bedrooms  bathrooms  \
# 0  2014-10-13 221900.000  7129300520  7129300520     3.000      1.000
# 1  2014-12-09 538000.000  6414100192  6414100192     3.000      2.250
# 2  2015-02-25 180000.000  5631500400  5631500400     2.000      1.000
# 3  2014-12-09 604000.000  2487200875  2487200875     4.000      3.000
# 4  2015-02-18 510000.000  1954400510  1954400510     3.000      2.000
#
#    sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  sqft_basement  \
# 0     1180.000  5650.000   1.000         NaN  ...    1180.000          0.000
# 1     2570.000  7242.000   2.000       0.000  ...    2170.000        400.000
# 2      770.000 10000.000   1.000       0.000  ...     770.000          0.000
# 3     1960.000  5000.000   1.000       0.000  ...    1050.000        910.000
# 4     1680.000  8080.000   1.000       0.000  ...    1680.000          0.000
#
#    yr_built  yr_renovated  zipcode    lat     long  sqft_living15  sqft_lot15  \
# 0      1955         0.000    98178 47.511 -122.257       1340.000    5650.000
# 1      1951     19910.000    98125 47.721 -122.319       1690.000    7639.000
# 2      1933           NaN    98028 47.738 -122.233       2720.000    8062.000
# 3      1965         0.000    98136 47.521 -122.393       1360.000    5000.000
# 4      1987         0.000    98074 47.617 -122.045       1800.000    7503.000
#
#    location_type
# 0          Urban
# 1          Urban
# 2          Urban
# 3          Urban
# 4          Urban
#
# [5 rows x 23 columns]

# %%
# Save to CSV
df_h1_final.to_csv('../data/processed/df_h1_final_cleaned.csv', index=False)
print("File saved successfully!")
# Out:
# File saved successfully!

# %%
import os
print(os.listdir('.'))  # List files in current directory
# Out:
# ['04a_H2_eda.ipynb', '04_eda_playground_data_cleaning.ipynb', '04a_H3_eda.ipynb', '04a_H1_eda_with_data_cleaning.ipynb', '04a_H1_eda.ipynb']
